# %% [markdown]
# # TOPIC : EXPLORATORY DATA ANALYSIS - RETAIL :

# %% [markdown]
# * We are try to perform our data analysis on the dataset 'samplesuperstore'.
#
# * As a business manager I'm trying to find out the weak areas where our team can work on for make a better profit.
#
# * We have to find all the problem areas by exploring the data.

# %% [markdown]
# ## Author : Piyali_Dey
# Copyright Piyali_Dey,2021

# %% [markdown]
# ### Importing The Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Read The DataSet

# %%
retail=pd.read_csv('SampleSuperstore.csv')
retail
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
#Read The top 5 records :
retail.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
#read the bottom 5 records
retail.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
#check the shape of the data
retail.shape
# Out:
# (9994, 13)

# %% [markdown]
# There are 9994 records and 13 features in the data.

# %%
#checking the information of the data
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
#checkin the 5point summery
retail.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# Here is all the statistical inferences from the dataset.we can see count,mean,std,min,max and percentile calculation

# %% [markdown]
# #### Seperated the categorical and the numerical column

# %%
cat_col=retail.select_dtypes('object')
num_col=retail.select_dtypes(np.number)

# %%
#finding the categorical columns:
cat_col.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Region',
#        'Category', 'Sub-Category'],
#       dtype='object')

# %%
#finding the numerical columns
num_col.columns
# Out:
# Index(['Postal Code', 'Sales', 'Quantity', 'Discount', 'Profit'], dtype='object')

# %% [markdown]
# ### Summerize the categorical column percentages :

# %%
print('% Values in each categorical columns in the dataset')
for k in cat_col:
    print('\n% Values in columns : ',k)
    print((retail[k].value_counts()/len(retail[k])*100))
# Out:
# % Values in each categorical columns in the dataset
#
# % Values in columns :  Ship Mode
# Standard Class    59.715829
# Second Class      19.461677
# First Class       15.389234
# Same Day           5.433260
# Name: Ship Mode, dtype: float64
#
# % Values in columns :  Segment
# Consumer       51.941165
# Corporate      30.218131
# Home Office    17.840704
# Name: Segment, dtype: float64
#
# % Values in columns :  Country
# United States    100.0
# Name: Country, dtype: float64
#
# % Values in columns :  City
# New York City     9.155493
# Los Angeles       7.474485
# Philadelphia      5.373224
# San Francisco     5.103062
# Seattle           4.282570
#                     ...
# Aberdeen          0.010006
# Lindenhurst       0.010006
# Santa Maria       0.010006
# Goldsboro         0.010006
# Citrus Heights    0.010006
# Name: City, Length: 531, dtype: float64
#
# % Values in columns :  State
# California              20.022013
# New York                11.286772
# ...

# %%
#find the duplicate records
retail.duplicated().sum()
# Out:
# 17

# %%
retail.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
#drop the duplicate 
retail.drop_duplicates(subset=None,keep='first',inplace=True)
retail.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Right now no duplicate records are available.

# %% [markdown]
# ### Checking The Null Values and percentage of the nulls in the dataset

# %%
number_of_missing_values = retail.isna().sum().sort_values(ascending=False)          
percentage_of_missing_values = (retail.isna().sum()*100/retail.isna().count()).sort_values(ascending=False)   
missing_data = pd.concat([number_of_missing_values,percentage_of_missing_values], axis = 1, keys = ['Total_Count', 'Percentage of Missing Values'])    
missing_data
# Out:
#               Total_Count  Percentage of Missing Values
# Profit                  0                           0.0
# Discount                0                           0.0
# Quantity                0                           0.0
# Sales                   0                           0.0
# Sub-Category            0                           0.0
# Category                0                           0.0
# Region                  0                           0.0
# Postal Code             0                           0.0
# State                   0                           0.0
# City                    0                           0.0
# Country                 0                           0.0
# Segment                 0                           0.0
# Ship Mode               0                           0.0

# %% [markdown]
# * There are no missing value in the dataset.

# %%
#Let's check the outliersin the dataset
retail.skew()
# Out:
# Postal Code    -0.127166
# Sales          12.963770
# Quantity        1.276709
# Discount        1.683386
# Profit          7.554748
# dtype: float64

# %% [markdown]
# * There are outlier presence in the dataset

# %% [markdown]
# #### Let's Check Out with Graphical Representation of Outliers :

# %%
plt.figure(figsize=(30,20))
s=1
for p in num_col:
    plt.subplot(4,3,s)
    sns.distplot(num_col[p])
    s+=1

# %% [markdown]
# * There Are Lots of outliers presence in some data.
#
# * We need to fix this by doing box-fox transform.
#
# * We will do it after our analysis and befor entering to the model building if needed,

# %% [markdown]
# # Start Aalysing The Data

# %% [markdown]
# ### Let's check the correlation matrix to find the correlation.

# %%
plt.figure(figsize=(10,6))
corr = retail.corr()
sns.heatmap(corr,annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# * There are no such correlation in the dataset neither dependent-independent nor       independent=independent.

# %%
retail = retail.drop(['Postal Code'],axis = 1)

# %% [markdown]
# ### Pair Plot Analysis :

# %%
sns.pairplot(retail)

# %% [markdown]
# * There are some relationship in some of the attributes.
#
# * sales-profit,discout-sales,quantity-discount we have to explore in some details

# %%
retail.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#   Region         Category Sub-Category     Sales  Quantity  Discount    Profit
# 0  South        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1  South        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2   West  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3  South        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  South  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %% [markdown]
# ## Some Univariate Analysis:

# %%
print('Explore the shipmode')
print(retail['Ship Mode'].value_counts())
plt.figure(figsize=(10,6))
retail['Ship Mode'].value_counts().plot(kind='bar',color=['blue','seagreen','yellow','orange'])
plt.xlabel('Ship Mode')
plt.ylabel('count')
# Out:
# Explore the shipmode
# Standard Class    5955
# Second Class      1943
# First Class       1537
# Same Day           542
# Name: Ship Mode, dtype: int64
# Text(0, 0.5, 'count')

# %% [markdown]
# * Standard Class ship mode is highly used.
# * Sameday used very less

# %%
print('Explore the segment')
print(retail['Ship Mode'].value_counts())
plt.figure(figsize=(10,6))
sns.countplot(x = 'Segment',data = retail, palette = 'rainbow')
# Out:
# Explore the segment
# Standard Class    5955
# Second Class      1943
# First Class       1537
# Same Day           542
# Name: Ship Mode, dtype: int64
# <AxesSubplot:xlabel='Segment', ylabel='count'>

# %%
print('Explore the country')
print(retail['Country'].value_counts())
# Out:
# Explore the country
# United States    9977
# Name: Country, dtype: int64

# %% [markdown]
# * Only country United States is in the dataset

# %%
plt.figure(figsize=(10,6))
retail['Region'].value_counts().plot(kind='bar',color=['yellow','orange','green','red'])
plt.xlabel('Region')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# * In the west region uses is pretty high
#
# * South region is compared to low

# %%
plt.figure(figsize=(10,6))
retail['Category'].value_counts().plot(kind='bar',color=['yellow','orange','green','red'])
plt.xlabel('Category')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# * Office Supplies Category is pretty high as compared to others.
#
# * Technical and furniture is same asper to the count

# %%
retail['Sub-Category'].value_counts()
# Out:
# Binders        1522
# Paper          1359
# Furnishings     956
# Phones          889
# Storage         846
# Art             795
# Accessories     775
# Chairs          615
# Appliances      466
# Labels          363
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
plt.figure(figsize=(15,12))
retail['Sub-Category'].value_counts().plot.pie(autopct='%2.2f%%')
plt.show()

# %% [markdown]
# * maximum are from the binders,paper,furnising,phone,storage
#
# * minumum is from copiers,machines.

# %%
plt.figure(figsize=(15,12))
sns.countplot(x='State',data=retail,palette='tab10',order=retail['State'].value_counts().index)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# * We can say that highest buyers are from california and newyork .
#
# * Lowest Buyers are from west virginia and wyoming.

# %%
retail.hist(figsize=(10,10),bins=50)
plt.show()

# %% [markdown]
# * Most customers tends to buy quantity of 2 and 3
#
# * Discount give maximum is 0 to 20 percent

# %% [markdown]
# ## Some Bivariate and Multivariate analysis

# %% [markdown]
# ### Profit Vs Discount & Profit Vs Quantity :

# %%
plt.figure(figsize=(30,15))
plt.subplot(1,2,1)
sns.lineplot(x='Discount',y='Profit',label='Profit',data=retail)
plt.title('PROFIT VS DISCOUNT',fontsize=20)

plt.subplot(1,2,2)
sns.lineplot(x='Quantity',y='Profit',label='Profit',data=retail)
plt.title('PROFIT VS QUANTITY',fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# * There are no correlation between discount and profit.
#
# * Ther are some relation between Quantity vs profit.

# %% [markdown]
# ### Segmentwise Sales and Profit

# %%
retail.groupby('Segment')[['Profit','Sales']].sum().plot.bar(color=['lightblue','blue'],figsize=(10,6))
plt.ylabel('Profit-Loss and sales')
plt.xlabel('Segments')
# Out:
# Text(0.5, 0, 'Segments')

# %% [markdown]
# * Profit and loss according to the sale is high in consumer segment.

# %% [markdown]
# ### region wise sales and profit

# %%
retail.groupby('Region')[['Profit','Sales']].sum().plot.bar(color=['lightblue','blue'],figsize=(10,6))
plt.ylabel('Profit/Loss and sales')
plt.show()

# %% [markdown]
# * Profit and Sales are high in the west region.
# * Profit and sales is very low in the central and south region.
# * We have to focus on the central and south region why the sales and profit is low

# %% [markdown]
# ### Region and segmentwise Sales and Profit

# %%
plt.figure(figsize=(12,8))
sns.set_palette('coolwarm_r')
plt.title('Segment wise Sales in each Region')
sns.barplot(x='Region',y='Sales',data=retail,hue='Segment',order=retail['Region'].value_counts().index)
plt.xlabel('Region',fontsize=15)
plt.show()

# %% [markdown]
# * region wise sales are almost same

# %% [markdown]
# ### Statewise Sales and Profit

# %%
retail.groupby('State')[['Sales','Profit']].sum().sort_values(by='Sales',ascending=False).plot(kind='bar',color=['blue','lightblue'],figsize=(14,6))
plt.title('Profit/loss & Sales across states')
plt.xlabel('States')
plt.ylabel('Profit/loss & Sales')
plt.show()

# %% [markdown]
# * Profit & Sales both are high in California and New york
#
# * Profit & Sales both are low in South west virginia and North Dekota
#
# * There are loss in texas pennsylvania,ohio,llinosis,north california.
#
# * We have to look into that states why the sales are so low we have to fix the problen to get   more profit.

# %%
t_states = retail['State'].value_counts().nlargest(10)
t_states
# Out:
# California        1996
# New York          1127
# Texas              983
# Pennsylvania       586
# Washington         502
# Illinois           491
# Ohio               468
# Florida            383
# Michigan           254
# North Carolina     249
# Name: State, dtype: int64

# %% [markdown]
# ### Profit-Loss vs Category

# %%
retail.groupby('Category')[['Profit','Sales']].sum().plot.bar(color=['blue','lightblue'],alpha=0.9,figsize=(12,6))
plt.ylabel('Profit/Loss and sales')
plt.show()

# %% [markdown]
# * Sales & Profit in the Technology category is very High rather than office supplies and furniture
#
# * Team need to focused on the furniture category for more profit.

# %% [markdown]
# ### Profit-Loss vs subcategory

# %%
retail.groupby('Sub-Category')[['Sales','Profit']].sum().sort_values(by='Sales',ascending=False).plot.bar(color=['blue','lightblue'],figsize=(15,8))
plt.title('Profit & loss & Sales across states')
plt.xlabel('Sub-Category')
plt.ylabel('Profit/loss & Sales')
plt.show()

# %% [markdown]
# * Phones sub-category have high sales.
# * chairs have high sales but less profit compared to phones
# * Tables and Bookmarks sub-categories facing huge loss

# %% [markdown]
# #### We Need to focus on the suggested region, suggested state,sub category table,category furniture to get more profit. after analysis everything is suggested above under each and every graph.
